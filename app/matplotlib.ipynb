# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from Tools.demo.sortvisu import steps

# %matplotlib inline

# %% [markdown]
# # Task 1 Line plot
#
# You have lists of `years` and `population`, complete the following tasks:
# * create a line plot;
# * set the title and labels for x and y axis;
# * set the title for the plot;
# * show it.
#
# > Please, note: you can get more information about line plot [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).

# %%
years = [2015, 2016, 2017, 2018, 2019]
population = [100, 120, 150, 180, 200]


plt.plot(years, population)
plt.title("Title")
plt.xlabel("Years")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# # Task 2 Scatter plot
#
# You have random data for `x` and `y`. Also, you have random `colors` and `sizes` for each point.
#
# Complete the following tasks:
# * create a scatter plot;
# * fill the plot with colors;
# * fill the plot with sizes;
# * set the title and labels for x and y axis;
# * set the colorbar label;
# * show it.
#
# > Please, note: you can get more information about scatter plot [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html).

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 100 * np.random.rand(50)

scatter = plt.scatter(x, y, c=colors, s=sizes, alpha=0.5)
plt.colorbar(scatter, label="Color Scale")
plt.show()
# write your code here

# %% [markdown]
# # Task 3 Bar plot
#
# You have lists of `categories` and `sales`, complete the following tasks:
# * create a bar plot;
# * set the title and labels for x and y axis;
# * rate the x ticks by 45 degrees;
# * show it.
#
# > Please, note: you can get more information about bar plot [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html).

# %%
categories = ["Category A", "Category B", "Category C", "Category D"]
sales = [350, 480, 210, 590]

plt.bar(categories, sales)
plt.title("Bar Chart")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Task 4 Histogram
#
# You have randomly generated data, complete the following tasks:
#
# * create a histogram;
# * set the title and labels for x and y axis;
# * make bins size not so wide;
# * show it.
#
# > Please, note: you can get more information about histogram [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html).

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, rwidth=0.5, bins=100)
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Task 5 Pie plot
#
# You have lists of `labels` and `market_share`, complete the following tasks:
# * create a pie plot;
# * set the title;
# * make numbers in format like `10.0%`;
# * set the start angle for better view;
# * show it.
#
# > Please, note: you can get more information about pie plot [here](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html).

# %%
labels = ["Product A", "Product B", "Product C", "Product D"]
market_share = [30, 20, 15, 35]
plt.pie(market_share, labels=labels, autopct="%1.1f%%", startangle=90)
# write your code here
# Out:
# ([<matplotlib.patches.Wedge at 0x159dc11b9d0>,
#   <matplotlib.patches.Wedge at 0x159dc11b910>,
#   <matplotlib.patches.Wedge at 0x159dc13c820>,
#   <matplotlib.patches.Wedge at 0x159dc13cfd0>],
#  [Text(-0.8899187390319623, 0.6465637152823859, 'Product A'),
#   Text(-0.6465639946425109, -0.8899185360649138, 'Product B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Product C'),
#   Text(0.9801069934445797, 0.49938990919023046, 'Product D')],
#  [Text(-0.4854102212901612, 0.3526711174267559, '30.0%'),
#   Text(-0.3526712698050059, -0.48541011058086203, '20.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5346038146061344, 0.27239449592194387, '35.0%')])

# %% [markdown]
# # Task 6 Subplots
#
# You have sin and cos functions, complete the following tasks:
#
# * create a figure with 2 subplots;
# * plot sin function in the first subplot;
# * plot cos function in the second subplot;
# * set the title and labels for x and y axis for each subplot;
# * set the title for the figure;
# * set different colors for each plot;
# * show it horizontally.
#
# > PLease, note: you can get more information about subplots [here](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html).

# %%
x = np.linspace(0, 5, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, (ax1, ax2) = plt.subplots(1, 2)
# Plot sin in first subplot
ax1.plot(x, y1, color="teal")
ax1.set_title("Sin")
ax1.set_xlabel("x")
ax1.set_ylabel("sin(x)")

# Plot cos in second subplot
ax2.plot(x, y2, color="orange")
ax2.set_title("Cos")
ax2.set_xlabel("x")
ax2.set_ylabel("cos(x)")

# Set main figure title
fig.suptitle("Sin and Cos")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Task 7 Time Series
#
# You have prepared data for time series, complete the following tasks:
#
# * create a line plot;
# * set the title and labels for x and y axis;
# * rotate x ticks by 45 degrees;
# * show it.
#
# > Please, note: you can get more information about time series [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html).

# %%
dates = pd.date_range("2023-01-01", "2023-12-31", freq="D")
values = pd.Series(range(len(dates)), index=dates)

plt.plot(dates, values)
plt.xticks(rotation=45)
plt.title("Dates")
plt.xlabel("Date")
plt.ylabel("Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 9
#       7 plt.xlabel("Date")
#       8 plt.ylabel("Value")
# ----> 9 plt.xticks(12)
#      10 plt.show()
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\pyplot.py:2238, in xticks(ticks, labels, minor, **kwargs)
#    2235         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2236                         "without setting 'ticks'")
#    2237 else:
# -> 2238     locs = ax.set_xticks(ticks, minor=minor)
#    2240 labels_out: list[Text] = []
#    2241 if labels is None:
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\axis.py:2218, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2213     first_key = next(iter(kwargs))
#    2214     raise ValueError(
#    2215         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2216         "other than 'minor' modify the text labels and can only be used if "
#    2217         "'labels' are passed as well.")
# -> 2218 result = self._set_tick_locations(ticks, minor=minor)
#    2219 if labels is not None:
#    2220     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\axis.py:2159, in Axis._set_tick_locations(self, ticks, minor)
#    2154 def _set_tick_locations(self, ticks, *, minor=False):
#    2155     # see docstring of set_ticks
#    2156
#    2157     # XXX if the user changes units, the information will be lost here
#    2158     ticks = self.convert_units(ticks)
# -> 2159     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2160     if len(ticks):
#    2161         for axis in self._get_shared_axis():
#    2162             # set_view_interval maintains any preexisting inversion.
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\ticker.py:1781, in FixedLocator.__init__(self, locs, nbins)
#    1779 def __init__(self, locs, nbins=None):
#    1780     self.locs = np.asarray(locs)
# -> 1781     _api.check_shape((None,), locs=self.locs)
#    1782     self.nbins = max(nbins, 2) if nbins is not None else None
#
# File D:\Projects\Python\tasks\py-matplotlib\.venv\lib\site-packages\matplotlib\_api\__init__.py:162, in check_shape(shape, **kwargs)
#     159 if len(shape) == 1:
#     160     text_shape += ","
# --> 162 raise ValueError(
#     163     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     164     f"but your input has shape {v.shape}"
#     165 )
#
# ValueError: 'locs' must be 1D with shape (N,), but your input has shape ()

# %% [markdown]
# # (Optional) Task 8 Surface 3D Plot
#
# You have prepared data for 3D surface plot, complete the following tasks:
# * create a figure;
# * add a subplot for 3D surface plot;
# * plot the surface, `cmap` can be `viridis`;
# * set the title and labels for x, y and z axis;
# * show it.
#
# > Please, note: you can get more information about 3D surface plot [here](https://matplotlib.org/stable/gallery/mplot3d/surface3d.html).

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# write your code here

# %% [markdown]
# # (Optional) Task 9
#
# You are working for a retail company that wants to understand its customer base better. The company has collected various demographic and purchasing behavior data for a sample of customers. Your task is to create a scatter plot matrix to visualize the relationships between different variables and identify potential customer segments based on their characteristics. The scatter plot matrix will allow you to observe the pairwise relationships between multiple variables simultaneously.
#
# > Please, note: you can find the file with data in the `data` folder.

# %%
# write your code here
